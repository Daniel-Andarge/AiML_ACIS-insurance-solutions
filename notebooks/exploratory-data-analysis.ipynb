# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import sys
import os

# %% [markdown]
# ## Import Functions

# %%
import sys
sys.path.append('../scripts')
from data_preparation_utills.data_preprocessor import *
from exploratory_data_analysis.data_understanding import *
from exploratory_data_analysis.visualization_handler import *

# %% [markdown]
# ## Load Cleaned Dataset

# %%
# path to the CSV file
filename = 'cleaned_MachineLearningRating_v3.csv'
path = os.path.join('..', 'local_storage', filename)

# Load dataset
cleaned_dataset = load_dataset(path)

# %%
display(cleaned_dataset)
# Out:
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827       2015-03-01             True
# 1                     145249     12827       2015-05-01             True
# 2                     145249     12827       2015-07-01             True
# 3                     145255     12827       2015-05-01             True
# 4                     145255     12827       2015-07-01             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389       2015-04-01            False
# 1000094                31520       389       2015-06-01            False
# 1000095                31520       389       2015-08-01            False
# 1000096                31519       389       2014-07-01            False
# 1000097                31519       389       2015-02-01            False
#
#         Citizenship          LegalType Title Language                 Bank  \
# ...

# %%
display(cleaned_dataset['SumInsured'])
# Out:
# 0                0.01
# 1                0.01
# 2                0.01
# 3           119300.00
# 4           119300.00
#               ...
# 1000093     500000.00
# 1000094     500000.00
# 1000095     500000.00
# 1000096    5000000.00
# 1000097    5000000.00
# Name: SumInsured, Length: 1000098, dtype: float64

# %% [markdown]
# ## Descriptive Statstics - Variability

# %%
columns = ['TotalPremium', 'TotalClaims','SumInsured', 'CalculatedPremiumPerTerm', 'CustomValueEstimate']
variability_result = calculate_variability(cleaned_dataset, columns)

# %%
display(variability_result)
# Out:
#                     TotalPremium   TotalClaims    SumInsured  \
# Range               66065.180175  4.050945e+05  1.263620e+07
# Variance            53030.956816  5.683812e+06  2.275065e+12
# Standard Deviation    230.284513  2.384075e+03  1.508332e+06
#
#                     CalculatedPremiumPerTerm  CustomValueEstimate
# Range                           74422.167900         2.653000e+07
# Variance                       159761.465821         3.186780e+11
# Standard Deviation                399.701721         5.645157e+05

# %% [markdown]
# ## Univariate Analysis - Charts

# %% [markdown]
# #### Plot histogram for numerical column

# %%
df_sample = cleaned_dataset.head(20)
numerical_column = 'TotalPremium'
plot_numerical_histograms(df_sample, numerical_column)

# %% [markdown]
# #### Plot bar chart for categorical column

# %%
df_sample = cleaned_dataset.head(20)
categorical_column = 'TotalPremium'
plot_categorical_barcharts(df_sample, categorical_column)
